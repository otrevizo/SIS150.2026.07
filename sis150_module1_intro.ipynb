# %% [markdown]
# <a href="https://colab.research.google.com/github/otrevizo/SIS150.2026.07/blob/main/sis150_module1_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 5

# %%
b = 10

# %%
result = a + b

# %%
print(result)
# Out:
# 15
